# %%
# !pip install datasets bert_score transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in ./.local/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: bert_score in ./.local/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: transformers in ./.local/lib/python3.11/site-packages (4.57.1)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in ./.local/lib/python3.11/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in ./.local/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in ./.local/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in ./.local/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./.local/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: torch>=1.0.0 in ./.local/lib/python3.11/site-packages (from bert_score) (2.9.0)
# Requirement already satisfied: matplotlib in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from bert_score) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in ./.local/lib/python3.11/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in ./.local/lib/python3.11/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.9.3)
# Requirement already satisfied: anyio in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.2.0)
# Requirement already satisfied: certifi in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in ./.local/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.4)
# Requirement already satisfied: h11>=0.16 in ./.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: sympy>=1.13.3 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.1)
# Requirement already satisfied: jinja2 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->bert_score) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->bert_score) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->bert_score) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->bert_score) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->bert_score) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->bert_score) (3.0.9)
# Requirement already satisfied: aiosignal>=1.1.2 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.9.3)
# Requirement already satisfied: six>=1.5 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.3)

# %%
from bert_score import score as bertscore_score
import random, re

DOC_COL = "document"
REF_COL = "summary"
SPLIT_TOKEN = "|||||"
RANDOM_SEED = 42

rng = random.Random(RANDOM_SEED)

def split_docs(multidoc_str: str):
    if not isinstance(multidoc_str, str):
        return []
    return [d.strip() for d in multidoc_str.split(SPLIT_TOKEN) if d and d.strip()]

def first_sentence(text: str):
    if not isinstance(text, str):
        return ""
    text = text.strip()
    if not text:
        return ""
    idx = text.find(".")
    if idx == -1:
        return text
    text = text[:idx+1].strip()
    parts = text.split("\n")  # at most 3 pieces
    # Keep everything after the second double newline if it exists
    return parts[-1].strip()

def get_ref(data):
    res = []
    for count, doc in enumerate(data):
        if len(doc) == 0:
            print("empty seq", count)
        docs = split_docs(doc)
        chosen_doc = rng.choice(docs)
        res.append(first_sentence(chosen_doc))
    return res

def predict_bias_scores(text: str):
    if not text or not text.strip():
        return np.zeros(7, dtype=float)
    rng = random.Random(hash(text) % (2**32))
    return np.array([rng.random() * 0.2 for _ in range(7)], dtype=float)

def compute_bertscore(cands, refs, model_type="roberta-large", lang="en"):
    P, R, F1 = bertscore_score(cands, refs, lang=lang, model_type=model_type)
    return np.array([f.item() for f in F1])

# %%
from datasets import load_dataset
import pandas as pd

dataset_train = load_dataset("Awesome075/multi_news_parquet", split="train").to_pandas()
dataset_test = load_dataset("Awesome075/multi_news_parquet", split="test").to_pandas()
dataset_val = load_dataset("Awesome075/multi_news_parquet", split="validation").to_pandas()
dataset_test.head(5)
# Out:
#                                             document  \
# 0  GOP Eyes Gains As Voters In 11 States Pick Gov...
# 1  \n \n \n \n UPDATE: 4/19/2001 Read Richard Met...
# 2  It's the Golden State's latest version of the ...
# 3  The seed for this crawl was a list of every ho...
# 4  After a year in which liberals scored impressi...
#
#                                              summary
# 0  – It's a race for the governor's mansion in 11...
# 1  – It turns out Facebook is only guilty of abou...
# 2  – Not a big fan of Southern California? Neithe...
# 3  – Why did Microsoft buy Nokia's phone business...
# 4  – The Supreme Court is facing a docket of high...

# %%
import numpy as np

dataset_test[DOC_COL].replace('', np.nan, inplace=True)
dataset_test[REF_COL].replace('', np.nan, inplace=True)
dataset_test.dropna(inplace=True)
refs = get_ref(dataset_test[DOC_COL])
print(refs[2])
# Out:
# The Siskiyou County Board of Supervisors voted 4-1 on Tuesday to support the county's split from the state of California.

# %%
actual = dataset_test[REF_COL].tolist()

scores = compute_bertscore(refs, actual)
print(scores)
# Out:
# 2025-11-05 21:36:26.840680: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-05 21:36:26.999964: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-05 21:36:32.303598: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [0.86647177 0.8404299  0.87250227 ... 0.8412149  0.81790543 0.85291541]

# %%
print(scores.mean())
# Out:
# 0.8299465036396454

# %%
from transformers import pipeline

# Load the model
classifier = pipeline(
    "text-classification",
    model="cirimus/modernbert-large-bias-type-classifier",
    top_k=None
)
# Out:
# Device set to use cuda:0
# /home/tmittal/.local/lib/python3.11/site-packages/torch/backends/cuda/__init__.py:131: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return torch._C._get_cublas_allow_tf32()
# [[{'label': 'political', 'score': 0.9999349117279053}, {'label': 'educational', 'score': 0.006539540830999613}, {'label': 'socioeconomic', 'score': 0.0035005114041268826}, {'label': 'age', 'score': 0.0015208054101094604}, {'label': 'religious', 'score': 0.000706337857991457}, {'label': 'nationality', 'score': 0.0006610832060687244}, {'label': 'racial', 'score': 0.00043269211892038584}, {'label': 'gender', 'score': 0.0002153290988644585}, {'label': 'disability', 'score': 0.00019418167357798666}, {'label': 'sexuality', 'score': 0.00011688211816363037}, {'label': 'physical', 'score': 4.504854587139562e-05}], [{'label': 'sexuality', 'score': 0.9419041872024536}, {'label': 'gender', 'score': 0.13597071170806885}, {'label': 'age', 'score': 0.10291977226734161}, {'label': 'political', 'score': 0.04822717607021332}, {'label': 'educational', 'score': 0.003797091543674469}, {'label': 'racial', 'score': 0.002407519845291972}, {'label': 'disability', 'score': 0.0013916435418650508}, {'label': 'physical', 'score': 0.0013883321080356836}, {'label': 'nationality', 'score': 0.0011251871474087238}, {'label': 'religious', 'score': 0.0007885863888077438}, {'label': 'socioeconomic', 'score': 0.0006402177968993783}], [{'label': 'political', 'score': 0.9373014569282532}, {'label': 'nationality', 'score': 0.2788361608982086}, {'label': 'racial', 'score': 0.21860934793949127}, {'label': 'socioeconomic', 'score': 0.02873487025499344}, {'label': 'educational', 'score': 0.012364351190626621}, {'label': 'religious', 'score': 0.004067739471793175}, {'label': 'sexuality', 'score': 0.0018985267961397767}, {'label': 'disability', 'score': 0.0012016084510833025}, {'label': 'age', 'score': 0.0008479620446451008}, {'label': 'gender', 'score': 0.0003040130250155926}, {'label': 'physical', 'score': 0.0001442734937882051}]]

# %%
def get_bias_scores(preds):
    return classifier(preds)

bias_scores = get_bias_scores(refs)
print(bias_scores[1])
# Out:
# [{'label': 'sexuality', 'score': 0.9419041872024536}, {'label': 'gender', 'score': 0.13597071170806885}, {'label': 'age', 'score': 0.10291977226734161}, {'label': 'political', 'score': 0.04822717607021332}, {'label': 'educational', 'score': 0.003797091543674469}, {'label': 'racial', 'score': 0.002407519845291972}, {'label': 'disability', 'score': 0.0013916435418650508}, {'label': 'physical', 'score': 0.0013883321080356836}, {'label': 'nationality', 'score': 0.0011251871474087238}, {'label': 'religious', 'score': 0.0007885863888077438}, {'label': 'socioeconomic', 'score': 0.0006402177968993783}]

# %%
def compute_neutrality(bias_output):
    scores = sorted([float(item["score"]) for item in bias_output], reverse=True)
    top3 = scores[:3] if len(scores) >= 3 else scores  # handle fewer categories
    avg_top3 = np.mean(top3)
    neutrality = (1.0 - avg_top3) ** 2
    return neutrality


neutrality_scores = [compute_neutrality(bias_score) for bias_score in bias_scores]

# %%
print(np.mean(neutrality_scores))
# Out:
# 0.48599172787542383

# %%
for i in range(3):
    print(refs[i][:10], actual[i][:20], scores[i], neutrality_scores[i])
# Out:
# Voters in  – It's a race for th 0.8664717674255371 0.44002218267265963
# It’s time  – It turns out Faceb 0.8404299020767212 0.3677231142683172
# The Siskiy – Not a big fan of S 0.8725022673606873 0.2722241179087657

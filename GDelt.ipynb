# %%
# !pip install gdelt datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 33.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.9/193.9 kB 17.0 MB/s eta 0:00:00
# ...

# %%
import gdelt
import pandas as pd

# Instantiate the gdeltPyR object
gd = gdelt.gdelt()

# Search for GDELT events within a date range and normalize column names
# Replace the dates with your desired range
events = gd.Search(date=['2023 Jan 01', '2023 Jan 07'], table='events', normcols=True)

# Display the first few rows of the DataFrame
print(events.head())
# Out:
# here
#    globaleventid   sqldate  monthyear  year  fractiondate actor1code  \
# 0     1078495007  20130104     201301  2013     2013.0110        BGD
# 1     1078495008  20130104     201301  2013     2013.0110        BGD
# 2     1078495009  20221203     202212  2022     2022.9123        THA
# 3     1078495010  20221203     202212  2022     2022.9123        USA
# 4     1078495011  20221203     202212  2022     2022.9123        USA
#
#       actor1name actor1countrycode actor1knowngroupcode actor1ethniccode  ...  \
# 0     BANGLADESH               BGD                  NaN              NaN  ...
# 1     BANGLADESH               BGD                  NaN              NaN  ...
# 2    PHATTHALUNG               THA                  NaN              NaN  ...
# 3  UNITED STATES               USA                  NaN              NaN  ...
# 4  UNITED STATES               USA                  NaN              NaN  ...
#
#   actiongeotype                            actiongeofullname  \
# ...

# %%
from datasets import load_dataset

train_dataset = load_dataset("alexfabbri/multi_news", split="train")
validation_dataset = load_dataset("alexfabbri/multi_news", split="validation")
test_dataset = load_dataset("alexfabbri/multi_news", split="test")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 3
#       1 from datasets import load_dataset
# ----> 3 train_dataset = load_dataset("alexfabbri/multi_news", split="train")
#       4 validation_dataset = load_dataset("alexfabbri/multi_news", split="validation")
#       5 test_dataset = load_dataset("alexfabbri/multi_news", split="test")
#
# File ~/.local/lib/python3.11/site-packages/datasets/load.py:1397, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1392 verification_mode = VerificationMode(
#    1393     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1394 )
#    1396 # Create a dataset builder
# ...
